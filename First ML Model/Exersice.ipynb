# %% [markdown]
# ## 🧠 Challenge 1: Fruit Guessing Upgrade
#
# **Task:**
# Add more fruits! 🍌🍇🍎
# Use features like **[weight, color_code]**
#
# **Color Code Example:**
# - Red = 0
# - Orange = 1
# - Yellow = 2 *(for banana)*
# - Purple = 3 *(for grapes)*
#
# ---
#
# **🔹 Hint:**
# ```python
# features = [[150,0],[170,0],[130,1],[120,1],[110,2],[50,3]]
# labels = ["apple","apple","orange","orange","banana","grapes"]
# ```
#
# ---
#
#
# - Question:
#     - Now predict for [100, 2] (yellow, light) — kya lagta hai?

# %%
from sklearn.tree import DecisionTreeClassifier
features = [[150,0],
[170,0],
[130,1],
[120,1],
[110,2],
[50,3]]
labels = ["apple", "apple", "orange", "orange","banana","grapes"]
clf = DecisionTreeClassifier()
clf = clf.fit(features,labels)
clf.predict([[100,2]])

# %% [markdown]
# ## ⚙️ Challenge 2: Human Height & Weight Classifier
#
# **Task:**
# Train a model to guess **“male or female”** using height and weight.
# Example features: **[height_cm, weight_kg]**
#
# ---
#
# **🔹 Hint:**
# ```python
# features = [[170,65],[160,55],[180,80],[155,45]]
# labels = ["male","female","male","female"]
# ```
# ---
# - Question:
#     - Now predict for [165, 60] — kya lagta hai?

# %%
from sklearn.tree import DecisionTreeClassifier
features = [
    [170,65],
    [160,55],
    [180,80],
    [155,45],

]
labels = ["male", "female", "male", "female"]
clf = DecisionTreeClassifier()
clf = clf.fit(features,labels)
clf.predict([[165,60]])

# %% [markdown]
# ## 🎯 Challenge 3: Pass or Fail Predictor
#
# **Task:**
# Build an ML model to predict if a student **passes or fails** based on their **marks**.
#
# ---
#
# **🔹 Hint:**
# ```python
# features = [[85],[40],[60],[90],[30]]
# labels = ["pass","fail","pass","pass","fail"]
# ```
# ---
# - Question:
#   - Predict for [75] — kya output milta hai?

# %%
from sklearn.tree import DecisionTreeClassifier
features = [
    [85],
    [40],
    [60],
    [90],
    [30],

]
labels = ["pass","fail","pass","pass","fail"]
clf = DecisionTreeClassifier()
clf = clf.fit(features,labels)
clf.predict([[75]])
# Out:
# array(['pass'], dtype='<U4')

# %% [markdown]
# ## 🌦️ Challenge 4: Weather Predictor
#
# **Task:**
# Predict **"Sunny"** or **"Rainy"** based on **temperature** and **humidity**.
#
# ---
#
# **🔹 Hint:**
# ```python
# features = [[30,60],[25,80],[35,50],[20,90]]
# labels = ["sunny","rainy","sunny","rainy"]
# ```
# ---
# - Question:
#   - Predict for [28, 70] — kya lagta hai?

# %%
from sklearn.tree import DecisionTreeClassifier
features = [
    [30,60],
    [25,80],
    [35,50],
    [20,90]
]
labels = ["sunny","rainy","sunny","rainy"]
clf = DecisionTreeClassifier()
clf = clf.fit(features,labels)
clf.predict([[28,70]])
# Out:
# array(['sunny'], dtype='<U5')

# %% [markdown]
# ## 🏠 Challenge 5: House Price Range
#
# **Task:**
# Predict **house price category** based on **area** and **number of bedrooms**.
# *(0 = Low, 1 = Medium, 2 = High)*
#
# ---
#
# **🔹 Hint:**
# ```python
# features = [[800,1],[1500,2],[2500,3],[1200,2]]
# labels = ["low","medium","high","medium"]
# ```
# ---
# - Question:
#     - Predict [2000, 3] — kya output?

# %%
from sklearn.tree import DecisionTreeClassifier
features = [
    [800,1],
    [1500,2],
    [2500,3],
    [1200,2]
]
labels = ["low","medium","high","medium"]
clf = DecisionTreeClassifier()
clf = clf.fit(features,labels)
clf.predict([[2000,3]])
# Out:
# array(['high'], dtype='<U6')

# %% [markdown]
# ## 📊 Bonus Challenge: Visualize Your Model
#
# **Task:**
# Use this snippet with **any of the above challenges** to visualize how your model makes decisions! 🌲🤖
#
# ---
#
# **🔹 Hint Code:**
# ```python
# from sklearn.tree import plot_tree
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(8,5))
# plot_tree(clf, filled=True, feature_names=["feature1", "feature2"], class_names=clf.classes_)
# plt.show()
# ```
#
# - *Pro Tip:*
#     - Change "feature1" and "feature2" to match your challenge — like "weight", "color_code", "marks", etc.

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.show()
plot_tree(clf, feature_names=["area", "bedrooms"], class_names=["low", "medium", "high"], filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'bedrooms <= 1.5\ngini = 0.625\nsamples = 4\nvalue = [1, 1, 2]\nclass = high'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = medium'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'bedrooms <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2]\nclass = high'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = high'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = low')]
